# %% [markdown]
# # Egg RGB image

# %%
from matplotlib import image as Img
from matplotlib import pyplot as plt
import numpy as np
picture = Img.imread("egg.jpg")
plt.imshow(picture)
plt.show()
print(picture)
# Out:
# [[[ 8  8  8]
#   [ 8  8  8]
#   [ 8  8  8]
#   ...
#   [ 7  7  7]
#   [ 7  7  7]
#   [ 7  7  7]]
#
#  [[ 7  7  7]
#   [ 7  7  7]
#   [ 7  7  7]
#   ...
#   [ 7  7  7]
#   [ 7  7  7]
#   [ 7  7  7]]
#
#  [[ 7  7  7]
#   [ 7  7  7]
#   [ 7  7  7]
#   ...
#   [ 7  7  7]
#   [ 7  7  7]
#   [ 7  7  7]]
#
#  ...
#
#  [[14 12 13]
#   [14 12 13]
#   [14 12 13]
#   ...
#   [15 13 14]
#   [15 13 14]
#   [15 13 14]]
#
#  [[14 12 13]
#   [14 12 13]
#   [14 12 13]
#   ...
#   [15 13 14]
#   [15 13 14]
#   [15 13 14]]
#
#  [[14 12 13]
#   [14 12 13]
#   [14 12 13]
#   ...
#   [15 13 14]
#   [15 13 14]
#   [15 13 14]]]

# %%
from matplotlib import image as Img
from matplotlib import pyplot as plt
import numpy as np
picture = Img.imread("egg.jpg")
plt.imshow(picture)
plt.show()
print(picture.shape)
print(picture)
# Out:
# (320, 480, 3)
# [[[ 8  8  8]
#   [ 8  8  8]
#   [ 8  8  8]
#   ...
#   [ 7  7  7]
#   [ 7  7  7]
#   [ 7  7  7]]
#
#  [[ 7  7  7]
#   [ 7  7  7]
#   [ 7  7  7]
#   ...
#   [ 7  7  7]
#   [ 7  7  7]
#   [ 7  7  7]]
#
#  [[ 7  7  7]
#   [ 7  7  7]
#   [ 7  7  7]
#   ...
#   [ 7  7  7]
#   [ 7  7  7]
#   [ 7  7  7]]
#
#  ...
#
#  [[14 12 13]
#   [14 12 13]
#   [14 12 13]
#   ...
#   [15 13 14]
#   [15 13 14]
#   [15 13 14]]
#
#  [[14 12 13]
#   [14 12 13]
#   [14 12 13]
#   ...
#   [15 13 14]
#   [15 13 14]
#   [15 13 14]]
#
#  [[14 12 13]
#   [14 12 13]
#   [14 12 13]
#   ...
#   [15 13 14]
#   [15 13 14]
#   [15 13 14]]]

# %%
from matplotlib import pyplot as plt
from matplotlib import image as Img
import numpy as np
picture = Img.imread("egg.jpg")
copie = np.copy(picture)
for i in range(320):
    for j in range(480):
        copie[i][j][0]=0

# %%
plt.imshow(copie)
plt.show()
print(copie)
# Out:
# [[[ 0  8  8]
#   [ 0  8  8]
#   [ 0  8  8]
#   ...
#   [ 0  7  7]
#   [ 0  7  7]
#   [ 0  7  7]]
#
#  [[ 0  7  7]
#   [ 0  7  7]
#   [ 0  7  7]
#   ...
#   [ 0  7  7]
#   [ 0  7  7]
#   [ 0  7  7]]
#
#  [[ 0  7  7]
#   [ 0  7  7]
#   [ 0  7  7]
#   ...
#   [ 0  7  7]
#   [ 0  7  7]
#   [ 0  7  7]]
#
#  ...
#
#  [[ 0 12 13]
#   [ 0 12 13]
#   [ 0 12 13]
#   ...
#   [ 0 13 14]
#   [ 0 13 14]
#   [ 0 13 14]]
#
#  [[ 0 12 13]
#   [ 0 12 13]
#   [ 0 12 13]
#   ...
#   [ 0 13 14]
#   [ 0 13 14]
#   [ 0 13 14]]
#
#  [[ 0 12 13]
#   [ 0 12 13]
#   [ 0 12 13]
#   ...
#   [ 0 13 14]
#   [ 0 13 14]
#   [ 0 13 14]]]

# %%
from matplotlib import image as Img
from matplotlib import pyplot as plt
import numpy as np
picture = Img.imread("egg.jpg")
copie1 = np.copy(picture)
for i in range(copie1.shape[0]):
    for j in range(copie1.shape[1]):
        copie1[i][j][1]=0

# %%
plt.imshow(copie1)
plt.show()
print(copie1)
# Out:
# [[[ 8  0  8]
#   [ 8  0  8]
#   [ 8  0  8]
#   ...
#   [ 7  0  7]
#   [ 7  0  7]
#   [ 7  0  7]]
#
#  [[ 7  0  7]
#   [ 7  0  7]
#   [ 7  0  7]
#   ...
#   [ 7  0  7]
#   [ 7  0  7]
#   [ 7  0  7]]
#
#  [[ 7  0  7]
#   [ 7  0  7]
#   [ 7  0  7]
#   ...
#   [ 7  0  7]
#   [ 7  0  7]
#   [ 7  0  7]]
#
#  ...
#
#  [[14  0 13]
#   [14  0 13]
#   [14  0 13]
#   ...
#   [15  0 14]
#   [15  0 14]
#   [15  0 14]]
#
#  [[14  0 13]
#   [14  0 13]
#   [14  0 13]
#   ...
#   [15  0 14]
#   [15  0 14]
#   [15  0 14]]
#
#  [[14  0 13]
#   [14  0 13]
#   [14  0 13]
#   ...
#   [15  0 14]
#   [15  0 14]
#   [15  0 14]]]

# %%
from matplotlib import image as Img
from matplotlib import pyplot as plt
import numpy as np
picture = Img.imread("egg.jpg")
copie2 = np.copy(picture)
for i in range(copie2.shape[0]):
    for j in range(copie2.shape[1]):
        copie2[i][j][2]=0

# %%
plt.imshow(copie2)
plt.show()
print(copie2)
# Out:
# [[[ 8  8  0]
#   [ 8  8  0]
#   [ 8  8  0]
#   ...
#   [ 7  7  0]
#   [ 7  7  0]
#   [ 7  7  0]]
#
#  [[ 7  7  0]
#   [ 7  7  0]
#   [ 7  7  0]
#   ...
#   [ 7  7  0]
#   [ 7  7  0]
#   [ 7  7  0]]
#
#  [[ 7  7  0]
#   [ 7  7  0]
#   [ 7  7  0]
#   ...
#   [ 7  7  0]
#   [ 7  7  0]
#   [ 7  7  0]]
#
#  ...
#
#  [[14 12  0]
#   [14 12  0]
#   [14 12  0]
#   ...
#   [15 13  0]
#   [15 13  0]
#   [15 13  0]]
#
#  [[14 12  0]
#   [14 12  0]
#   [14 12  0]
#   ...
#   [15 13  0]
#   [15 13  0]
#   [15 13  0]]
#
#  [[14 12  0]
#   [14 12  0]
#   [14 12  0]
#   ...
#   [15 13  0]
#   [15 13  0]
#   [15 13  0]]]

# %%
from matplotlib import image as Img
from matplotlib import pyplot as plt
import numpy as np
picture = Img.imread("egg.jpg")
copie3 = np.copy(picture)
for i in range(copie3.shape[0]):
    for j in range(copie3.shape[1]):
        copie3[i][j][1]=0
        copie3[i][j][2]=0

# %%
plt.imshow(copie3)
plt.show()
print(copie3)
# Out:
# [[[ 8  0  0]
#   [ 8  0  0]
#   [ 8  0  0]
#   ...
#   [ 7  0  0]
#   [ 7  0  0]
#   [ 7  0  0]]
#
#  [[ 7  0  0]
#   [ 7  0  0]
#   [ 7  0  0]
#   ...
#   [ 7  0  0]
#   [ 7  0  0]
#   [ 7  0  0]]
#
#  [[ 7  0  0]
#   [ 7  0  0]
#   [ 7  0  0]
#   ...
#   [ 7  0  0]
#   [ 7  0  0]
#   [ 7  0  0]]
#
#  ...
#
#  [[14  0  0]
#   [14  0  0]
#   [14  0  0]
#   ...
#   [15  0  0]
#   [15  0  0]
#   [15  0  0]]
#
#  [[14  0  0]
#   [14  0  0]
#   [14  0  0]
#   ...
#   [15  0  0]
#   [15  0  0]
#   [15  0  0]]
#
#  [[14  0  0]
#   [14  0  0]
#   [14  0  0]
#   ...
#   [15  0  0]
#   [15  0  0]
#   [15  0  0]]]

# %%
from matplotlib import image as Img
from matplotlib import pyplot as plt
import numpy as np
picture = Img.imread("egg.jpg")
copie4 = np.copy(picture)
for i in range(copie4.shape[0]):
    for j in range(copie4.shape[1]):
        copie4[i][j][0]=0
        copie4[i][j][2]=0

# %%
plt.imshow(copie4)
plt.show()
print(copie4)
# Out:
# [[[ 0  8  0]
#   [ 0  8  0]
#   [ 0  8  0]
#   ...
#   [ 0  7  0]
#   [ 0  7  0]
#   [ 0  7  0]]
#
#  [[ 0  7  0]
#   [ 0  7  0]
#   [ 0  7  0]
#   ...
#   [ 0  7  0]
#   [ 0  7  0]
#   [ 0  7  0]]
#
#  [[ 0  7  0]
#   [ 0  7  0]
#   [ 0  7  0]
#   ...
#   [ 0  7  0]
#   [ 0  7  0]
#   [ 0  7  0]]
#
#  ...
#
#  [[ 0 12  0]
#   [ 0 12  0]
#   [ 0 12  0]
#   ...
#   [ 0 13  0]
#   [ 0 13  0]
#   [ 0 13  0]]
#
#  [[ 0 12  0]
#   [ 0 12  0]
#   [ 0 12  0]
#   ...
#   [ 0 13  0]
#   [ 0 13  0]
#   [ 0 13  0]]
#
#  [[ 0 12  0]
#   [ 0 12  0]
#   [ 0 12  0]
#   ...
#   [ 0 13  0]
#   [ 0 13  0]
#   [ 0 13  0]]]

# %%
from matplotlib import image as Img
from matplotlib import pyplot as plt
import numpy as np
picture = Img.imread("egg.jpg")
copie5 = np.copy(picture)
for i in range(copie5.shape[0]):
    for j in range(copie5.shape[1]):
        copie5[i][j][0]=0
        copie5[i][j][1]=0

# %%
plt.imshow(copie5)
plt.show()
print(copie5)
# Out:
# [[[ 0  0  8]
#   [ 0  0  8]
#   [ 0  0  8]
#   ...
#   [ 0  0  7]
#   [ 0  0  7]
#   [ 0  0  7]]
#
#  [[ 0  0  7]
#   [ 0  0  7]
#   [ 0  0  7]
#   ...
#   [ 0  0  7]
#   [ 0  0  7]
#   [ 0  0  7]]
#
#  [[ 0  0  7]
#   [ 0  0  7]
#   [ 0  0  7]
#   ...
#   [ 0  0  7]
#   [ 0  0  7]
#   [ 0  0  7]]
#
#  ...
#
#  [[ 0  0 13]
#   [ 0  0 13]
#   [ 0  0 13]
#   ...
#   [ 0  0 14]
#   [ 0  0 14]
#   [ 0  0 14]]
#
#  [[ 0  0 13]
#   [ 0  0 13]
#   [ 0  0 13]
#   ...
#   [ 0  0 14]
#   [ 0  0 14]
#   [ 0  0 14]]
#
#  [[ 0  0 13]
#   [ 0  0 13]
#   [ 0  0 13]
#   ...
#   [ 0  0 14]
#   [ 0  0 14]
#   [ 0  0 14]]]

# %% [markdown]
# # Satellite image Convert into RGB

# %%
from matplotlib import image as Img
from matplotlib import pyplot as plt
import numpy as np
picture = Img.imread("k.jpg")
plt.imshow(picture)
plt.show()
print(picture)
# Out:
# [[[109 126 156]
#   [ 85  98 142]
#   [ 80  91 145]
#   ...
#   [138 124 121]
#   [130 119 117]
#   [114 102 104]]
#
#  [[ 96 111 130]
#   [109 123 152]
#   [ 97 106 149]
#   ...
#   [128 114 111]
#   [115 103 103]
#   [107  95  97]]
#
#  [[119 128 137]
#   [120 127 145]
#   [110 117 145]
#   ...
#   [114 100  99]
#   [106  94  94]
#   [108  96  98]]
#
#  ...
#
#  [[114 120 146]
#   [113 119 145]
#   [112 118 144]
#   ...
#   [166 138 117]
#   [166 138 117]
#   [166 138 117]]
#
#  [[115 121 147]
#   [115 121 147]
#   [115 121 147]
#   ...
#   [167 139 118]
#   [167 139 118]
#   [167 139 118]]
#
#  [[113 119 143]
#   [113 119 143]
#   [116 122 146]
#   ...
#   [167 140 119]
#   [166 139 118]
#   [166 139 118]]]

# %%
print(picture.shape)
# Out:
# (897, 1021, 3)

# %%
from matplotlib import image as Img
from matplotlib import pyplot as plt
import numpy as np
picture = Img.imread("k.jpg")
copie7 = np.copy(picture)
for i in range(copie7.shape[0]):
    for j in range(copie7.shape[1]):
        copie7[i][j][1]=0
        copie7[i][j][2]=0

# %%
plt.imshow(copie7)
plt.show()
print(copie7)
# Out:
# [[[109   0   0]
#   [ 85   0   0]
#   [ 80   0   0]
#   ...
#   [138   0   0]
#   [130   0   0]
#   [114   0   0]]
#
#  [[ 96   0   0]
#   [109   0   0]
#   [ 97   0   0]
#   ...
#   [128   0   0]
#   [115   0   0]
#   [107   0   0]]
#
#  [[119   0   0]
#   [120   0   0]
#   [110   0   0]
#   ...
#   [114   0   0]
#   [106   0   0]
#   [108   0   0]]
#
#  ...
#
#  [[114   0   0]
#   [113   0   0]
#   [112   0   0]
#   ...
#   [166   0   0]
#   [166   0   0]
#   [166   0   0]]
#
#  [[115   0   0]
#   [115   0   0]
#   [115   0   0]
#   ...
#   [167   0   0]
#   [167   0   0]
#   [167   0   0]]
#
#  [[113   0   0]
#   [113   0   0]
#   [116   0   0]
#   ...
#   [167   0   0]
#   [166   0   0]
#   [166   0   0]]]

# %%
from matplotlib import image as Img
from matplotlib import pyplot as plt
import numpy as np
picture = Img.imread("k.jpg")
copie8 = np.copy(picture)
for i in range(copie8.shape[0]):
    for j in range(copie8.shape[1]):
        copie8[i][j][0]=0
        copie8[i][j][2]=0
plt.imshow(copie8)
plt.show()
print(copie8)
# Out:
# [[[  0 126   0]
#   [  0  98   0]
#   [  0  91   0]
#   ...
#   [  0 124   0]
#   [  0 119   0]
#   [  0 102   0]]
#
#  [[  0 111   0]
#   [  0 123   0]
#   [  0 106   0]
#   ...
#   [  0 114   0]
#   [  0 103   0]
#   [  0  95   0]]
#
#  [[  0 128   0]
#   [  0 127   0]
#   [  0 117   0]
#   ...
#   [  0 100   0]
#   [  0  94   0]
#   [  0  96   0]]
#
#  ...
#
#  [[  0 120   0]
#   [  0 119   0]
#   [  0 118   0]
#   ...
#   [  0 138   0]
#   [  0 138   0]
#   [  0 138   0]]
#
#  [[  0 121   0]
#   [  0 121   0]
#   [  0 121   0]
#   ...
#   [  0 139   0]
#   [  0 139   0]
#   [  0 139   0]]
#
#  [[  0 119   0]
#   [  0 119   0]
#   [  0 122   0]
#   ...
#   [  0 140   0]
#   [  0 139   0]
#   [  0 139   0]]]

# %%
from matplotlib import image as Img
from matplotlib import pyplot as plt
import numpy as np
picture = Img.imread("k.jpg")
copie9 = np.copy(picture)
for i in range(copie9.shape[0]):
    for j in range(copie9.shape[1]):
        copie8[i][j][0]=0
        copie8[i][j][1]=0
plt.imshow(copie9)
plt.show()
print(copie9)
# Out:
# [[[109 126 156]
#   [ 85  98 142]
#   [ 80  91 145]
#   ...
#   [138 124 121]
#   [130 119 117]
#   [114 102 104]]
#
#  [[ 96 111 130]
#   [109 123 152]
#   [ 97 106 149]
#   ...
#   [128 114 111]
#   [115 103 103]
#   [107  95  97]]
#
#  [[119 128 137]
#   [120 127 145]
#   [110 117 145]
#   ...
#   [114 100  99]
#   [106  94  94]
#   [108  96  98]]
#
#  ...
#
#  [[114 120 146]
#   [113 119 145]
#   [112 118 144]
#   ...
#   [166 138 117]
#   [166 138 117]
#   [166 138 117]]
#
#  [[115 121 147]
#   [115 121 147]
#   [115 121 147]
#   ...
#   [167 139 118]
#   [167 139 118]
#   [167 139 118]]
#
#  [[113 119 143]
#   [113 119 143]
#   [116 122 146]
#   ...
#   [167 140 119]
#   [166 139 118]
#   [166 139 118]]]
